# %%
#Answer 1)
'''GET Method
The Hypertext Transfer Protocol(HTTP) GET method is mainly used on the client (Browser) side to send a request to
specified server to get certain data or resources. Using this method the server should only let us receive the data 
and not its state. Hence it it only used to view something and not to change it. The request parameter of the get method
is appended to the URL. GET request is better for the data which does not need to be secure(It means the data which 
does not contain images or word documents)

POST Method
The Hypertext Transefer Protocol(HTTP) POST method is mainly used at the client (Browser) side to send data to a 
specified server in order to create or rewrite a particular resouce/data. This data sent to the server is stored in 
the request body of the HTTP request. POST method eventually leads to the creation of a new resource or updating an
existing one. The data that is been sent is included in the body of the request and not in the URL.'''

# %%
#Answer 2)
'''In flask, request is used to send data from webpage(client) to server. The Request, in Flask, is an object that 
contains all the data sent from the client to server. This data can be recovered using the GET/POST methods.'''

# %%
#Answer 3)
'''A redirect is used in the FLask class to send the user to a particular URL with the status code. When we access 
a website, out browser sends a request to the server, and server replies with what is known as the HTTP status code,
which is a three-digit number.'''

# %%
#Answer 4)
'''In Flask, templates are used to generate dynamic HTML content. They are essentially HTML files with placeholders
for dynamic data. The The render_template function in Flask is used to render HTML templates.'''

# %%
#Answer 5)

# %% [markdown]
# ![http___127.0.0.1_5000_postman_data%20-%20My%20Workspace%202_4_2024%2012_00_52%20PM.png](attachment:http___127.0.0.1_5000_postman_data%20-%20My%20Workspace%202_4_2024%2012_00_52%20PM.png)

# %% [markdown]
# ![http___127.0.0.1_5000_postman_data%20-%20My%20Workspace%202_4_2024%2012_01_30%20PM.png](attachment:http___127.0.0.1_5000_postman_data%20-%20My%20Workspace%202_4_2024%2012_01_30%20PM.png)

# %% [markdown]
# ![http___127.0.0.1_5000_postman_data%20-%20My%20Workspace%202_4_2024%2012_02_24%20PM.png](attachment:http___127.0.0.1_5000_postman_data%20-%20My%20Workspace%202_4_2024%2012_02_24%20PM.png)

# %% [markdown]
# ![http___127.0.0.1_5000_postman_data%20-%20My%20Workspace%202_4_2024%2012_02_59%20PM.png](attachment:http___127.0.0.1_5000_postman_data%20-%20My%20Workspace%202_4_2024%2012_02_59%20PM.png)
